# %%
import pandas as pd
import numpy as np

# %%
imdb = pd.read_csv('IMDB Dataset.csv')

# %%
imdb.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
imdb.describe()
# Out:
#                                                    review sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %%
imdb['review'].head()
# Out:
# 0    One of the other reviewers has mentioned that ...
# 1    A wonderful little production. <br /><br />The...
# 2    I thought this was a wonderful way to spend ti...
# 3    Basically there's a family where a little boy ...
# 4    Petter Mattei's "Love in the Time of Money" is...
# Name: review, dtype: object

# %%
# how many different kind of values are there inside the column 
imdb['sentiment'].unique()
# Out:
# array(['positive', 'negative'], dtype=object)

# %%
# count of the different values 
imdb['sentiment'].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
imdb.iloc[0:10]
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
# 5  Probably my all-time favorite movie, a story o...  positive
# 6  I sure would like to see a resurrection of a u...  positive
# 7  This show was an amazing, fresh & innovative i...  negative
# 8  Encouraged by the positive comments about this...  negative
# 9  If you like original gut wrenching laughter yo...  positive

# %%
# get rows 10 to 15 and column 1
imdb.iloc[9:15,1]
# Out:
# 9     positive
# 10    negative
# 11    negative
# 12    negative
# 13    negative
# 14    positive
# Name: sentiment, dtype: object

# %%
imdb.loc[:99,['sentiment']]
# Out:
#    sentiment
# 0   positive
# 1   positive
# 2   positive
# 3   negative
# 4   positive
# ..       ...
# 95  positive
# 96  negative
# 97  negative
# 98  negative
# 99  positive
#
# [100 rows x 1 columns]

# %% [markdown]
# ## Boolean Subsetting

# %%
x = pd.Series(list(range(100,110)))
x
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# 5    105
# 6    106
# 7    107
# 8    108
# 9    109
# dtype: int64

# %%
x<104
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
x[x>104]
# Out:
# 5    105
# 6    106
# 7    107
# 8    108
# 9    109
# dtype: int64

# %%
x[(x>10) & (x<107)]
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# 5    105
# 6    106
# dtype: int64

# %%
x[x!=101]
# Out:
# 0    100
# 2    102
# 3    103
# 4    104
# 5    105
# 6    106
# 7    107
# 8    108
# 9    109
# dtype: int64

# %%
imdb[imdb.sentiment=='positive']
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# 5      Probably my all-time favorite movie, a story o...  positive
# ...                                                  ...       ...
# 49983  I loved it, having been a fan of the original ...  positive
# 49985  Imaginary Heroes is clearly the best film of t...  positive
# 49989  I got this one a few weeks ago and love it! It...  positive
# 49992  John Garfield plays a Marine who is blinded by...  positive
# 49995  I thought this movie did a down right good job...  positive
#
# [25000 rows x 2 columns]

# %%
imdb[imdb['sentiment']=='positive'].shape
# Out:
# (25000, 2)

# %%
len(imdb[imdb['sentiment']=='positive'])
# Out:
# 25000

# %% [raw]
# Create new columns

# %%
#can use .operator too
imdb['profit']=0
imdb.head()
# Out:
#                                               review sentiment  profit
# 0  One of the other reviewers has mentioned that ...  positive       0
# 1  A wonderful little production. <br /><br />The...  positive       0
# 2  I thought this was a wonderful way to spend ti...  positive       0
# 3  Basically there's a family where a little boy ...  negative       0
# 4  Petter Mattei's "Love in the Time of Money" is...  positive       0

# %%
imdb1 = imdb[imdb['sentiment']=='positive']

# %%
imdb1['profit']=0
imdb1.head()
# Out:
# /var/folders/3f/5mbkppp90kz2z80jjyn8m2cc0000gp/T/ipykernel_848/2534540210.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb1['profit']=0
#                                               review sentiment  profit
# 0  One of the other reviewers has mentioned that ...  positive       0
# 1  A wonderful little production. <br /><br />The...  positive       0
# 2  I thought this was a wonderful way to spend ti...  positive       0
# 4  Petter Mattei's "Love in the Time of Money" is...  positive       0
# 5  Probably my all-time favorite movie, a story o...  positive       0

# %%
imdb1.iloc[imdb1.profit.argmax()]
# Out:
# review       One of the other reviewers has mentioned that ...
# sentiment                                             positive
# profit                                                       0
# Name: 0, dtype: object

# %%
imdb1.loc[imdb1.profit.argmax()]
# Out:
# review       One of the other reviewers has mentioned that ...
# sentiment                                             positive
# profit                                                       0
# Name: 0, dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
imdb1['perc'] = imdb1.profit+imdb1.profit
# Out:
# /var/folders/3f/5mbkppp90kz2z80jjyn8m2cc0000gp/T/ipykernel_848/553629842.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb1['perc'] = imdb1.profit+imdb1.profit

# %%
imdb1.columns
# Out:
# Index(['review', 'sentiment', 'profit', 'perc'], dtype='object')

# %%
imdb1.loc[imdb['sentiment']=='positive']
# Out:
#                                                   review sentiment  profit
# 0      One of the other reviewers has mentioned that ...  positive       0  \
# 1      A wonderful little production. <br /><br />The...  positive       0
# 2      I thought this was a wonderful way to spend ti...  positive       0
# 4      Petter Mattei's "Love in the Time of Money" is...  positive       0
# 5      Probably my all-time favorite movie, a story o...  positive       0
# ...                                                  ...       ...     ...
# 49983  I loved it, having been a fan of the original ...  positive       0
# 49985  Imaginary Heroes is clearly the best film of t...  positive       0
# 49989  I got this one a few weeks ago and love it! It...  positive       0
# 49992  John Garfield plays a Marine who is blinded by...  positive       0
# 49995  I thought this movie did a down right good job...  positive       0
#
#        perc
# 0         0
# 1         0
# 2         0
# 4         0
# ...

# %%
imdb1.drop([0,2],axis=0,inplace=True)
# Out:
# /var/folders/3f/5mbkppp90kz2z80jjyn8m2cc0000gp/T/ipykernel_848/2304693892.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb1.drop([0,2],axis=0,inplace=True)

# %%
imdb1.head()
# Out:
#                                               review sentiment  profit  perc
# 1  A wonderful little production. <br /><br />The...  positive       0     0
# 4  Petter Mattei's "Love in the Time of Money" is...  positive       0     0
# 5  Probably my all-time favorite movie, a story o...  positive       0     0
# 6  I sure would like to see a resurrection of a u...  positive       0     0
# 9  If you like original gut wrenching laughter yo...  positive       0     0

# %%
imdb1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24998 entries, 1 to 49995
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     24998 non-null  object
#  1   sentiment  24998 non-null  object
#  2   profit     24998 non-null  int64
#  3   perc       24998 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 976.5+ KB

# %%
imdb1['profit']=np.random.randint(10,500,24998)
# Out:
# /var/folders/3f/5mbkppp90kz2z80jjyn8m2cc0000gp/T/ipykernel_848/3882554001.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb1['profit']=np.random.randint(10,500,24998)

# %%
imdb1.head()
# Out:
#                                               review sentiment  profit  perc
# 1  A wonderful little production. <br /><br />The...  positive     475     0
# 4  Petter Mattei's "Love in the Time of Money" is...  positive     180     0
# 5  Probably my all-time favorite movie, a story o...  positive     347     0
# 6  I sure would like to see a resurrection of a u...  positive     466     0
# 9  If you like original gut wrenching laughter yo...  positive     317     0

# %%
imdb1['budget'] =  np.random.randint(0,200,24998)
# Out:
# /var/folders/3f/5mbkppp90kz2z80jjyn8m2cc0000gp/T/ipykernel_848/469827525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb1['budget'] =  np.random.randint(0,200,24998)

# %%
imdb1.head()
# Out:
#                                               review sentiment  profit  perc
# 1  A wonderful little production. <br /><br />The...  positive     475     0  \
# 4  Petter Mattei's "Love in the Time of Money" is...  positive     180     0
# 5  Probably my all-time favorite movie, a story o...  positive     347     0
# 6  I sure would like to see a resurrection of a u...  positive     466     0
# 9  If you like original gut wrenching laughter yo...  positive     317     0
#
#    budget
# 1     131
# 4      88
# 5     177
# 6      51
# 9     154

# %%
imdb1.drop(['perc'],axis=1,inplace=True)
# Out:
# /var/folders/3f/5mbkppp90kz2z80jjyn8m2cc0000gp/T/ipykernel_848/3189263069.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb1.drop(['perc'],axis=1,inplace=True)

# %%
imdb1['perc'] = (imdb1.profit/imdb1.budget)*100
# Out:
# /var/folders/3f/5mbkppp90kz2z80jjyn8m2cc0000gp/T/ipykernel_848/2633604646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb1['perc'] = (imdb1.profit/imdb1.budget)*100

# %%
imdb1.head()
# Out:
#                                               review sentiment  profit
# 1  A wonderful little production. <br /><br />The...  positive     475  \
# 4  Petter Mattei's "Love in the Time of Money" is...  positive     180
# 5  Probably my all-time favorite movie, a story o...  positive     347
# 6  I sure would like to see a resurrection of a u...  positive     466
# 9  If you like original gut wrenching laughter yo...  positive     317
#
#    budget        perc
# 1     131  362.595420
# 4      88  204.545455
# 5     177  196.045198
# 6      51  913.725490
# 9     154  205.844156

# %%
imdb1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24998 entries, 1 to 49995
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     24998 non-null  object
#  1   sentiment  24998 non-null  object
#  2   profit     24998 non-null  int64
#  3   budget     24998 non-null  int64
#  4   perc       24998 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.1+ MB

# %%
imdb1.iloc[3:10,2]
# Out:
# 6     466
# 9     317
# 14    350
# 16     53
# 18    458
# 20    438
# 22     41
# Name: profit, dtype: int64

# %%
imdb1.replace(imdb1.iloc[3:10,2],np.nan,inplace=True)

# %%
imdb1
# Out:
#                                                   review sentiment  profit
# 1      A wonderful little production. <br /><br />The...  positive     475  \
# 4      Petter Mattei's "Love in the Time of Money" is...  positive     180
# 5      Probably my all-time favorite movie, a story o...  positive     347
# 6      I sure would like to see a resurrection of a u...  positive     466
# 9      If you like original gut wrenching laughter yo...  positive     317
# ...                                                  ...       ...     ...
# 49983  I loved it, having been a fan of the original ...  positive     199
# 49985  Imaginary Heroes is clearly the best film of t...  positive      76
# 49989  I got this one a few weeks ago and love it! It...  positive     201
# 49992  John Garfield plays a Marine who is blinded by...  positive      88
# 49995  I thought this movie did a down right good job...  positive      45
#
#        budget         perc   2
# 1         131   362.595420 NaN
# ...

# %%
imdb1.fillna(0,inplace=True)
# Out:
# /var/folders/3f/5mbkppp90kz2z80jjyn8m2cc0000gp/T/ipykernel_848/3179756700.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb1.fillna(0,inplace=True)

# %%
imdb1
# Out:
#                                                   review sentiment  profit
# 1      A wonderful little production. <br /><br />The...  positive     475  \
# 4      Petter Mattei's "Love in the Time of Money" is...  positive     180
# 5      Probably my all-time favorite movie, a story o...  positive     347
# 6      I sure would like to see a resurrection of a u...  positive     466
# 9      If you like original gut wrenching laughter yo...  positive     317
# ...                                                  ...       ...     ...
# 49983  I loved it, having been a fan of the original ...  positive     199
# 49985  Imaginary Heroes is clearly the best film of t...  positive      76
# 49989  I got this one a few weeks ago and love it! It...  positive     201
# 49992  John Garfield plays a Marine who is blinded by...  positive      88
# 49995  I thought this movie did a down right good job...  positive      45
#
#        budget         perc    2
# 1          40   362.595420  0.0
# ...

# %%
imdb1[imdb1['budget']==0]
# Out:
#                                                   review sentiment  profit
# 481    Things to Come is an early Sci-Fi film that sh...  positive     235  \
# 492    In an alternate 1950s, where an outbreak of th...  positive     190
# 1325   52-Pick Up never got the respect it should hav...  positive     454
# 1345   "Yes, Georgio" is a light-hearted and enjoyabl...  positive     226
# 1393   Walt Disney's 20th animated feature was the la...  positive     162
# ...                                                  ...       ...     ...
# 48083  Crackerjack is a funny movie, everyone at the ...  positive      73
# 48214  I like this episode quite a bit, Ruth Gordon i...  positive     167
# 49508  For avid Sci-Fi fans this movie is just what y...  positive     282
# 49622  Where do I begin? Walt Disney's happiest motio...  positive      19
# 49804  ***May Contain Spoilers*** OK, it wasn't exact...  positive     204
#
#        budget         perc    2
# 481         0  1236.842105  0.0
# ...

# %%
len(imdb1[imdb1['budget']==0])
# Out:
# 132

# %%
(imdb1['budget']==0).sum()
# Out:
# 132

# %%
imdb_new = imdb1[imdb1['budget']!=0]
imdb_new
# Out:
#                                                   review sentiment  profit
# 1      A wonderful little production. <br /><br />The...  positive     475  \
# 4      Petter Mattei's "Love in the Time of Money" is...  positive     180
# 5      Probably my all-time favorite movie, a story o...  positive     347
# 6      I sure would like to see a resurrection of a u...  positive     466
# 9      If you like original gut wrenching laughter yo...  positive     317
# ...                                                  ...       ...     ...
# 49983  I loved it, having been a fan of the original ...  positive     199
# 49985  Imaginary Heroes is clearly the best film of t...  positive      76
# 49989  I got this one a few weeks ago and love it! It...  positive     201
# 49992  John Garfield plays a Marine who is blinded by...  positive      88
# 49995  I thought this movie did a down right good job...  positive      45
#
#        budget         perc    2
# 1          40   362.595420  0.0
# ...

# %%
len(imdb_new[imdb_new['budget']==0])
# Out:
# 0

# %%
imdb_new.perc = (imdb_new.profit/imdb_new.budget)*100
imdb_new.drop(2,axis=1,inplace=True)
# Out:
# /var/folders/3f/5mbkppp90kz2z80jjyn8m2cc0000gp/T/ipykernel_848/3133848871.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   imdb_new.perc = (imdb_new.profit/imdb_new.budget)*100
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[130], line 3
#       1 imdb_new.perc = (imdb_new.profit/imdb_new.budget)*100
# ----> 3 imdb_new.drop(2,axis=1,inplace=True)
#       4 imdb_new.describe()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
# ...

# %%
imdb_new.describe()
# Out:
#              profit        budget          perc
# count  24866.000000  24866.000000  24866.000000
# mean     254.854661     99.692874    759.588752
# std      141.322848     57.486406   2566.645676
# min       10.000000      1.000000      5.128205
# 25%      132.000000     50.000000    132.625980
# 50%      255.000000    100.000000    256.048780
# 75%      377.000000    149.000000    516.304348
# max      499.000000    199.000000  48300.000000

# %% [markdown]
# ## Merge and Concat Df

# %%
cereals = pd.read_csv('cereal.csv')
plants = pd.read_csv('data.csv')

# %%
new_df = pd.concat([cereals,plants],axis=1)

# %%
cereals.shape
# Out:
# (77, 16)

# %%
plants.shape
# Out:
# (569, 33)

# %%
cereals.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber
# 0                  100% Bran   N    C        70        4    1     130   10.0  \
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
cereals
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber
# 0                   100% Bran   N    C        70        4    1     130   10.0  \
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
plants.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0    842302         M        17.99         10.38          122.80     1001.0  \
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 0          0.11840           0.27760          0.3001              0.14710  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
new_df
# Out:
#                           name  mfr type  calories  protein  fat  sodium
# 0                    100% Bran    N    C      70.0      4.0  1.0   130.0  \
# 1            100% Natural Bran    Q    C     120.0      3.0  5.0    15.0
# 2                     All-Bran    K    C      70.0      4.0  1.0   260.0
# 3    All-Bran with Extra Fiber    K    C      50.0      4.0  0.0   140.0
# 4               Almond Delight    R    C     110.0      2.0  2.0   200.0
# ..                         ...  ...  ...       ...      ...  ...     ...
# 564                        NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 565                        NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 566                        NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 567                        NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 568                        NaN  NaN  NaN       NaN      NaN  NaN     NaN
#
#      fiber  carbo  sugars  ...  texture_worst  perimeter_worst  area_worst
# ...

# %%
new_df_2 = pd.concat([cereals,plants],axis=0)
new_df_2
# Out:
#                           name  mfr type  calories  protein  fat  sodium
# 0                    100% Bran    N    C      70.0      4.0  1.0   130.0  \
# 1            100% Natural Bran    Q    C     120.0      3.0  5.0    15.0
# 2                     All-Bran    K    C      70.0      4.0  1.0   260.0
# 3    All-Bran with Extra Fiber    K    C      50.0      4.0  0.0   140.0
# 4               Almond Delight    R    C     110.0      2.0  2.0   200.0
# ..                         ...  ...  ...       ...      ...  ...     ...
# 564                        NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 565                        NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 566                        NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 567                        NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 568                        NaN  NaN  NaN       NaN      NaN  NaN     NaN
#
#      fiber  carbo  sugars  ...  texture_worst  perimeter_worst  area_worst
# ...

# %%
date = '2/10/1968'

# %%
from datetime import datetime

# %%
new_date = datetime.strptime(date, "%m/%d/%Y")

# %%
new_date
# Out:
# datetime.datetime(1968, 2, 10, 0, 0)
