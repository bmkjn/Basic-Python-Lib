# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
cars = pd.read_csv('auto-mpg.csv')
cars.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year
# 0  18.0          8         307.0        130    3504          12.0          70  \
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
sns.lineplot(data=cars,x='weight',y='acceleration')
# Out:
# <Axes: xlabel='weight', ylabel='acceleration'>

# %%
cars['origin']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 393    1
# 394    2
# 395    1
# 396    1
# 397    1
# Name: origin, Length: 398, dtype: int64

# %%
cars['origin'].value_counts()
# Out:
# origin
# 1    249
# 3     79
# 2     70
# Name: count, dtype: int64

# %%
# changing datatype
cars['origin']=cars['origin'].astype(str)

# %%
sns.barplot(data=cars,x='origin',y='mpg')
# Out:
# <Axes: xlabel='origin', ylabel='mpg'>

# %%
df = pd.DataFrame(cars['origin'].value_counts())
df.head()
# Out:
#         count
# origin
# 1         249
# 3          79
# 2          70

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#   origin  count
# 0      1    249
# 1      3     79
# 2      2     70

# %%
sns.barplot(data=df,x='origin',y='count')
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
sns.histplot(data=cars,x='weight')
# Out:
# <Axes: xlabel='weight', ylabel='Count'>

# %%
sns.histplot(data=cars,x='displacement')
# Out:
# <Axes: xlabel='displacement', ylabel='Count'>

# %%
sns.scatterplot(data=cars,x='weight',y='displacement')
# Out:
# <Axes: xlabel='weight', ylabel='displacement'>

# %%
sns.scatterplot(data=cars,x='weight',y='displacement',hue='origin')
# Out:
# <Axes: xlabel='weight', ylabel='displacement'>

# %%
sns.scatterplot(data=cars,y='weight',x='displacement',hue='cylinders')
# all the cars with low weight and low displacement have less number of cylinders.
# Out:
# <Axes: xlabel='displacement', ylabel='weight'>
